# %% [markdown]
# - - -

# %% [markdown]
# # **California House Pricing**
#
# Data tersebut berisi informasi dari sensus California tahun 1990. Jadi, meskipun hal ini mungkin tidak membantu Anda dalam memprediksi harga rumah saat ini, hal ini memberikan kumpulan data pengenalan yang dapat diakses untuk mengajari orang-orang tentang dasar-dasar pembelajaran mesin.
#
# Data tersebut berkaitan dengan rumah-rumah yang ditemukan di distrik California tertentu dan beberapa ringkasan statistik berdasarkan data sensus tahun 1990.

# %% [markdown]
# [California House Pricing]()
#
# ## **Content**
#
# **A. Business Problem Understanding**
#
# **B. Data Understanding**
#
# **C. Explanatory Data Analysis**
#
# **D. Data Preprocessing**
#
# **E. Machine Learning Modeling**
#
# **F. Conclusion and Recommendation**
#
# <br>
#
# ****

# %% [markdown]
# ## **A. Bussiness Problem Understanding**

# %% [markdown]
# ### **1. Context**
#
# Sebuah hunian merupakan kebutuhan paling primer setiap individu manusia, oleh karena itu tempat tinggal menjadi hal paling mendasar dalam kehidupan manusia. Tempat tinggal saat ini memiliki berbagai pilihan mulai dari pilihan harga, luas bangunan, wilayah, dll. Banyak orang awam merasa sulit untuk mengetahui harga rumah sesuai yang paling sesuai. Begitu juga di Negara Amerika Serikat khususnya daerah California, yang terletak dibagian Barat Amerika. Hal ini pun menjadi tantangan sekaligus kesempatan bagi para developer rumah untuk dapat membangun suatu hunian dengan harga yang kompetitif dan memiliki fasilitas yang sesuai dengan kebutuhan untuk para calon orang yang akan menghuni rumah tersebut.

# %% [markdown]
# ### **2. Problem Statement**
#
# Setiap developer memiliki tantangan bagaimana menentukan harga rumah yang tepat, namun dengan tetap memperhatikan fasilitas yang diberikan, dan juga aspek pendukung lainnya. Dalam pasar properti yang kompetitif, agen perlu memberikan nilai tambah yang signifikan kepada klien mereka untuk memenangkan kepercayaan dan mendapatkan bisnis. Salah satu tantangan utama adalah menentukan harga yang akurat dan kompetitif untuk properti yang akan dijual. Faktor-faktor seperti kondisi pasar, lokasi, dan fitur properti dapat mempengaruhi harga, dan membuat penentuan harga yang salah dapat mengakibatkan keuntungan yang kurang optimal atau kesulitan dalam menjual properti. Para developer akan salah langkah jika membangun suatu hunian mewah, namun di daerah yang memiliki penghasilan yang rendah atau pun hunian yang biasa-biasa saja (notebene kecil) di kawasan orang yang berpenghasilan tinggi. Developer mempunyai tantangan bagaimana cara agar keuntungan finansial yang mereka dapat bisa secara maksimal.

# %% [markdown]
# ### **3. Goals**

# %% [markdown]
# Tujuan dari pemodelan machine learning ini adalah:
#
# 1. Penentuan harga jual rumah, pada dataset berdasarkan berbagai aspek seperti : lokasi, umur bangunan, jumlah ruangan, jumlah kamar tidur, populasi, pendapatan, dan seberapa jauh dengan pantai.
# 2. Menentukan aspek paling penting dalam perhitungan harga rumah itu sendiri, seberapa besar korelasinya dengan harga rumah
# 3. Output bisa digunakan sebagai Pricing strategy kedepannya, untuk meminimalisir overpricing atau underpricing saat penentuan harga suatu rumah.

# %% [markdown]
# ### **4. Analytic Approach**
#
# Pada tahap ini, akan dilakukan analisis untuk bisa menemukan pola dari fitur yang ada pada dataset. Bisa dilihat dengan cara membangun suatu model machine learning yang berfungsi untuk memprediksi harga jual rumah, yang nantinya akan berguna bagi pihak developer dalam penentuan harga rumah di suatu kawasan. Dengan membangun suatu model machine learning regresi, diharapkan bisa membantu dalam proses penentuan harga berdasarkan fitur yang tersedia pada dataset.

# %% [markdown]
# ### **5. Modeling**
#
# Dari dataset yang diberikan, akan ditentukan label sehingga dapat digunakan sebuah model machine learning supervised. Karena targetnya berupa numerik yang continous, akan dilakukan model machine learning regresi untuk memprediksi harga rumah berdasarkan feature yang ada. Berikut model regresi yang akan dipakai:

# %% [markdown]
# ### a. [Linear Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)

# %% [markdown]
# LinearRegression cocok diterapkan pada model linier dengan koefisien w = (w1, …, wp) untuk meminimalkan sisa penjumlahan kuadrat antara target yang diamati dalam dataset, dan target yang diprediksi oleh pendekatan linier.

# %% [markdown]
# ### b. [KNN Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)

# %% [markdown]
# Regresi berdasarkan k-nearest neighbors.
# Target diprediksi dengan interpolasi lokal dari target yang terasosiasi dengan nearest neighbors dalam training set.

# %% [markdown]
# ### c. [Decision Tree Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)

# %% [markdown]
# Decision tree regression mengamati object features dan men-train model dalam struktur tree untuk memprediksi future data yang kontinu. Output nya tidak diskrit, yaitu tidak hanya diwakili oleh kumpulan angka atau nilai yang diketahui dan terpisah.

# %% [markdown]
# ### d. [Random Forest Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)

# %% [markdown]
# Random forest adalah meta estimator yang cocok dengan classifying decision trees pada berbagai sub-sampel dari kumpulan data dan menggunakan rata-rata untuk meningkatkan akurasi prediksi dan kontrol over-fitting. Ukuran sub-sampel dikontrol dengan parameter `max_samples` jika `bootstrap=True` (default), jika tidak seluruh dataset digunakan untuk membangun setiap tree.

# %% [markdown]
# ### e. [XGBoost Regressor](https://machinelearningmastery.com/xgboost-for-regression/)

# %% [markdown]
# Extreme Gradient Boosting (XGBoost) adalah open-source library yang menyediakan implementasi yang efisien dan efektif dari algoritma gradient boosting.

# %% [markdown]
# ### f. [Support Vector Regression](https://www.analyticsvidhya.com/blog/2020/03/support-vector-regression-tutorial-for-machine-learning/)

# %% [markdown]
# Support Vector Machines (SVM) populer dan banyak digunakan untuk masalah klasifikasi dalam pembelajaran mesin. Saya sering mengandalkan hal ini tidak hanya dalam proyek pembelajaran mesin tetapi juga ketika saya menginginkan hasil cepat dalam hackathon.
#
# Tapi SVM untuk analisis regresi? Aku bahkan belum mempertimbangkan kemungkinan itu selama beberapa waktu! Dan bahkan sekarang ketika saya membahas “Dukungan Regresi Vektor” di hadapan para pemula pembelajaran mesin, saya sering kali mendapat ekspresi bingung. Saya mengerti – sebagian besar kursus dan pakar bahkan tidak menyebutkan Support Vector Regression (SVR) sebagai algoritma pembelajaran mesin.

# %% [markdown]
# ### g. [Lasso Regressor](https://machinelearningmastery.com/lasso-regression-with-python/)

# %% [markdown]
# Regresi Lasso adalah jenis regresi linier teregulasi populer yang menyertakan penalti L1. Hal ini berdampak pada menyusutnya koefisien variabel masukan yang tidak memberikan kontribusi banyak pada tugas prediksi. Penalti ini memungkinkan beberapa nilai koefisien menuju ke nilai nol, sehingga variabel masukan dapat dihapus secara efektif dari model, menyediakan jenis pemilihan fitur otomatis

# %% [markdown]
# ### **6. Evaluation Metric**

# %% [markdown]
# Untuk model machine learning regresi, terdapat berbagai metriks evaluasi yang dapat digunakan:
# 1. RMSE: Nilai rata-rata dari selisih kuadrat antara nilai prediksi dan nilai aktual (error), kemudian diakarkan.
# 2. MAE: Nilai rata-rata dari absolut selisih antara nilai prediksi dan nilai aktual (error)
# 3. MAPE: Nilai rata-rata persentase dari dari selisih kuadrat antara nilai prediksi dan nilai aktual (error)

# %% [markdown]
# - - -

# %% [markdown]
# ## **B. Data Understanding**

# %% [markdown]
# ### **1. Column Description**

# %% [markdown]
# Digunakan dataset `data_california_house.csv`. Dataset ini dapat diunduh [di laman ini](https://www.kaggle.com/datasets/camnugent/california-housing-prices)

# %% [markdown]
# Berikut Penjelasan kolom pada dataset.
#
# | No | Nama Kolom | Deskripsi & Penjelasan Kolom |
# | -- | -- | -- |
# | 1 | longitude | Ukuran seberapa jauh barat sebuah rumah; nilai yang lebih besar lebih jauh ke barat |
# | 2 | latitude | Ukuran seberapa jauh utara sebuah rumah; nilai yang lebih besar lebih jauh ke utara |
# | 3 | housingMedianAge | Usia rata-rata sebuah rumah dalam satu blok; angka yang lebih rendah adalah bangunan yang lebih baru |
# | 4 | totalRooms | Jumlah total ruangan dalam satu blok |
# | 5 | totalBedrooms | Jumlah total kamar tidur dalam satu blok |
# | 6 | population | Jumlah total orang yang tinggal dalam satu blok |
# | 7 | households | Jumlah total rumah tangga (Jumlah kepala dalam satu), sekelompok orang yang tinggal di dalam satu unit rumah, untuk satu blok |
# | 8 | medianIncome | Median pendapatan untuk rumah tangga dalam satu blok rumah (diukur dalam puluhan ribu Dolar AS)| |
# | 9 | medianHouseValue | Median harga rumah rata-rata untuk rumah tangga dalam satu blok (diukur dalam Dolar AS) |
# | 10 | oceanProximity | Jarak rumah ke pesisir pantai atau laut |

# %% [markdown]
# Berdasarkan dataset, berkaitan dengan konteks bisnis, didapat sebagai berikut:
# `medianIncome` merupakan hal penting ditinjau dari aspek bisnis. Pendapatan seseorang yang tinggi, otomatis akan mampu membeli properti yang harganya tinggi pula.
#
# `housingMedianAge` juga merupakan aspek penting, karena sudah berapa rata-rata usia bangunan yang ada pada kawasan tersebut. Akan mempengaruhi seberapa besar harga jual rumah tersebut.
#
# `totalRooms` dan `totalBedrooms`menjadi penting, karena bisa menjadi keputusan akan difungsikan sebagai apa rumah tersebut. Apakah sebagai hunian pribadi/disewakan lagi kepada orang lain.

# %% [markdown]
# ### **2. Import Libraries**

# %%
# import libraries
import pandas as pd
import numpy as np

# vlisualization
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **3. Load Dataset**
#
# Dataset merupakan file dengan ekstensi .csv

# %%
# load dataset, dan isiniasi menjadi df
df = pd.read_csv('data_california_house.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.79     36.73                52.0        112.0            28.0
# 1        -122.21     37.77                43.0       1017.0           328.0
# 2        -118.04     33.87                17.0       2358.0           396.0
# 3        -118.28     34.06                17.0       2518.0          1196.0
# 4        -119.81     36.73                50.0        772.0           194.0
# ...          ...       ...                 ...          ...             ...
# 14443    -121.26     38.27                20.0       1314.0           229.0
# 14444    -120.89     37.48                27.0       1118.0           195.0
# 14445    -121.90     36.58                31.0       1431.0             NaN
# 14446    -117.93     33.62                34.0       2125.0           498.0
# 14447    -115.56     32.80                15.0       1171.0           328.0
#
# ...

# %% [markdown]
# Melakukan duplikasi data, untuk menjaga data asli

# %%
df_duplicate = df.copy()

# %% [markdown]
# - - -

# %% [markdown]
# ## **C. Explanatory Data Analysis**

# %% [markdown]
# Exploratory Data Analysis adalah suatu proses uji investigasi awal yang bertujuan untuk mengidentifikasi pola, menemukan anomali, menguji hipotesis dan memeriksa asumsi. Dengan melakukan EDA, pengguna akan sangat terbantu dalam mendeteksi kesalahan dari awal, dapat mengidentifikasi outlier, mengetahui hubungan antar data serta dapat menggali faktor-faktor penting dari data. Proses EDA ini sangat bermanfaat dalam proses analisis statistik.

# %% [markdown]
# Mengecek informasi terkait dataset

# %%
df_duplicate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           14448 non-null  float64
#  1   latitude            14448 non-null  float64
#  2   housing_median_age  14448 non-null  float64
#  3   total_rooms         14448 non-null  float64
#  4   total_bedrooms      14311 non-null  float64
#  5   population          14448 non-null  float64
#  6   households          14448 non-null  float64
#  7   median_income       14448 non-null  float64
#  8   ocean_proximity     14448 non-null  object
#  9   median_house_value  14448 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# Terdapat 10 kolom, dan total 14.448 baris data pada dataset ini. Terdapat missing value pada kolom `total_bedrooms`. Memiliki type data adalah float, kecuali pada kolom `ocean_proximity` yang type datanya objek.

# %%
df_duplicate.hist(bins=50, figsize=(15,10))
plt.show()

# %% [markdown]
# ### **1. Data Numerical**

# %%
df_duplicate.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14448.000000  14448.000000        14448.000000  14448.000000
# mean    -119.566647     35.630093           28.618702   2640.132683
# std        2.006587      2.140121           12.596694   2191.612441
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.490000     34.260000           29.000000   2125.000000
# 75%     -118.000000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14311.000000  14448.000000  14448.000000   14448.000000
# mean       538.260709   1425.157323    499.508929       3.866667
# std        423.577544   1149.580157    383.098390       1.891158
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ### **2. Data Kategorikal**

# %%
df.describe(include='object')
# Out:
#        ocean_proximity
# count            14448
# unique               5
# top          <1H OCEAN
# freq              6369

# %% [markdown]
# Menampilkan Informasi pada Dataset

# %%
sns.scatterplot(data=df_duplicate, x='longitude', y='latitude', hue='ocean_proximity')
plt.title('Ocean Proximity berdasarkan Latitude and Longitude')
plt.show()

# %% [markdown]
# Dapat dilihat bahwa warna biru merupakan daratan, merah merupakan rumah dekat pantai, warna hijau adalah rumah yang jarak ke pantainya <1 jam, orange merupakan rumah dekat teluk, dan ungu adalah pulau dan ditampilkan berdasarkan latitude dan longitude nya.

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6369
# INLAND        4576
# NEAR OCEAN    1879
# NEAR BAY      1622
# ISLAND           2
# Name: count, dtype: int64

# %% [markdown]
# Selanjutnya akan dilakukan plot untuk Target yaitu `median_house_value`

# %%
sns.scatterplot(data=df_duplicate, x='longitude', y='latitude',hue='median_house_value')
plt.title('Nilai Rumah berdasarkan Latitude dan Longitude')
plt.show()

# %%
sns.scatterplot(data=df_duplicate, x='longitude', y='latitude',hue='median_income')
plt.title('Pendapatan Perkapita berdasarkan Latitude dan Longitude')
plt.show()

# %% [markdown]
# Ternyata nilai mayoritas rumah yang tinggi berada didekat pantai atau pelabuhan

# %%
groupby_median = df_duplicate['median_house_value'].groupby(df_duplicate['ocean_proximity']).median().reset_index()
groupby_median.sort_values('median_house_value',ascending=False)
# Out:
#   ocean_proximity  median_house_value
# 2          ISLAND            351100.0
# 3        NEAR BAY            230800.0
# 4      NEAR OCEAN            228600.0
# 0       <1H OCEAN            214800.0
# 1          INLAND            108800.0

# %% [markdown]
# - - -

# %% [markdown]
# ## **D. Data Preprocessing**

# %% [markdown]
# ### **1. Tentang Dataset**

# %% [markdown]
# Menampilkan keseluruhan nilai deskripsi statistik pada seluruh kolom

# %%
df_duplicate.describe(include='all')
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   14448.000000  14448.000000        14448.000000  14448.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.566647     35.630093           28.618702   2640.132683
# std         2.006587      2.140121           12.596694   2191.612441
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1451.000000
# 50%      -118.490000     34.260000           29.000000   2125.000000
# 75%      -118.000000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  32627.000000
#
#         total_bedrooms    population    households  median_income  \
# count     14311.000000  14448.000000  14448.000000   14448.000000
# ...

# %% [markdown]
# Beberapa kolom merupakan right skewness karena nilai mean nya jauh diatas median, yaitu pada kolom `total_rooms`, `total_bedrooms`, `population`, `households`, `median_income`, dan `median_house_value`
#
# Selanjutnya akan ditampilkan menggunakan histogram untuk melihat persebaran data nya

# %%
df_duplicate.hist(bins=50,figsize=(10,10))
plt.show()

# %% [markdown]
# Semua kolom memiliki distribusi data right skewness, kecuali pada kolom `latitude`, `longitude`, dan `housing_median_age`.

# %% [markdown]
# ### **2. Data Duplikat**

# %% [markdown]
# Mengecek data duplikat pada dataset

# %%
df_duplicate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Tidak terdapat data yang duplikat pada dataset

# %% [markdown]
# ### **3. Missing Value**

# %% [markdown]
# Mengecek missing value pada dataset

# %%
listItem = []

for col in df_duplicate.columns:
    listItem.append([col, df_duplicate[col].dtype, df_duplicate[col].isnull().sum(), round((df_duplicate[col].isnull().sum()/len(df_duplicate[col]))*100, 2),
                    df_duplicate[col].nunique(), list(df_duplicate[col].drop_duplicates().sample(5).values)])

df_duplicate_desc = pd.DataFrame(columns=['Column', 'Dtype', 'null count', 'null perc.', 'unique count', 'unique sample'],
                     data=listItem)
df_duplicate_desc
# Out:
#                Column    Dtype  null count  null perc.  unique count  \
# 0           longitude  float64           0        0.00           806
# 1            latitude  float64           0        0.00           836
# 2  housing_median_age  float64           0        0.00            52
# 3         total_rooms  float64           0        0.00          5227
# 4      total_bedrooms  float64         137        0.95          1748
# 5          population  float64           0        0.00          3498
# 6          households  float64           0        0.00          1649
# 7       median_income  float64           0        0.00          9797
# 8     ocean_proximity   object           0        0.00             5
# 9  median_house_value  float64           0        0.00          3548
#
#                                        unique sample
# 0       [-117.92, -118.6, -116.44, -117.04, -122.28]
# 1                [37.41, 35.34, 37.44, 36.95, 38.31]
# ...

# %% [markdown]
# Missing value hanya terdapat pada kolom `total_bedrooms` yaitu sebanyak 137 atau 0.95 % saja. Maka dari itu akan dilakukan tindakan berupa penghapusan data tersebut.

# %%
df_duplicate.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        137
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
# menghapus missing value
df_duplicate = df_duplicate.dropna()

# %%
df_duplicate.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %% [markdown]
# ### **4. Outlier dan Anomali Data**

# %%
num_features = [feature for feature in df_duplicate.columns if ((df_duplicate[feature].dtypes != 'object'))]
df_duplicate[num_features].describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14311.000000  14311.000000        14311.000000  14311.000000
# mean    -119.567150     35.631365           28.609671   2640.917686
# std        2.006374      2.139589           12.606493   2197.192896
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1452.000000
# 50%     -118.490000     34.260000           29.000000   2125.000000
# 75%     -118.000000     37.715000           37.000000   3142.000000
# max     -114.310000     41.950000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14311.000000  14311.000000  14311.000000   14311.000000
# mean       538.260709   1424.772273    499.480470       3.866774
# std        423.577544   1151.795857    383.826005       1.890866
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Mengecek outliers pada setiap kolom yang ada

# %%
plt.figure(figsize=(20, 10), facecolor='white')
sns.set(style='whitegrid')
plotnumber = 1

for num in num_features:
    ax = plt.subplot(3,3, plotnumber)
    sns.boxplot(x=num, data=df_duplicate, palette='crest')
    plt.title(num, fontsize=16)
    plt.tight_layout()
    plotnumber += 1
plt.show()

# %% [markdown]
# Dari plot diatas, didapat informasi bahwa terdapat outlier pada kolom `total_rooms`, `total_bedrooms`, `population`, `households`, `median_house_value`, dan `median_income`. Sedangkan pada kolom `housing_median_age`, `longitude`, `latitude` tidak terdapat outlier.

# %% [markdown]
# Mengecek value yang dirasa abnormal pada kolom `housing_median_age` dan `median_house_value`

# %%
excluded_columns = ['longitude', 'latitude','ocean_proximity']  # List of columns to exclude
selected_columns = df.drop(excluded_columns, axis=1)



for column in selected_columns.columns:
    q1 = selected_columns[column].quantile(0.25)
    q3 = selected_columns[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Check for outliers
    outliers = selected_columns[(selected_columns[column] < lower_bound) | (selected_columns[column] > upper_bound)]

    print(f"Outliers di column '{column}': {((selected_columns[column] > upper_bound) | (selected_columns[column] < lower_bound)).sum()}")

    print(f"Lower bound: {lower_bound}")
    print(f"Upper bound: {upper_bound}")
    print("-----BATAS-----")
# Out:
# Outliers di column 'housing_median_age': 0
# Lower bound: -10.5
# Upper bound: 65.5
# -----BATAS-----
# Outliers di column 'total_rooms': 900
# Lower bound: -1094.5
# Upper bound: 5693.5
# -----BATAS-----
# Outliers di column 'total_bedrooms': 879
# Lower bound: -233.0
# Upper bound: 1175.0
# -----BATAS-----
# Outliers di column 'population': 827
# Lower bound: -626.0
# Upper bound: 3134.0
# -----BATAS-----
# Outliers di column 'households': 842
# Lower bound: -208.5
# Upper bound: 1091.5
# -----BATAS-----
# Outliers di column 'median_income': 482
# Lower bound: -0.6776500000000012
# Upper bound: 7.984350000000001
# -----BATAS-----
# Outliers di column 'median_house_value': 757
# Lower bound: -96850.0
# Upper bound: 480350.0
# -----BATAS-----

# %%
df_duplicate['median_house_value'].value_counts().head(10)
# Out:
# median_house_value
# 500001.0    672
# 137500.0     82
# 162500.0     78
# 225000.0     69
# 187500.0     69
# 112500.0     66
# 350000.0     56
# 87500.0      50
# 67500.0      47
# 150000.0     46
# Name: count, dtype: int64

# %% [markdown]
# Terdapat anomali pada kolom `median_house_value` dimana nilainya 500.001, sedangkan nilai lainnya memiliki 2 angka terakhir 00. nilai `median_house_value` yang akan dikelompokkan hanya yang bernilai 500.000 saja

# %%
df_duplicate.drop(df_duplicate[df_duplicate['median_house_value']==500001.0].index, inplace=True)

# %%
# fungsi untuk mengecek outliers
def anomalies(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    limit_bawah = q1 - limit
    limit_atas = q3 + limit
    print(f'limit_bawah: {limit_bawah}')
    print(f'limit_atas: {limit_atas}')

# %%
anomalies(df_duplicate['median_house_value'])
# Out:
# IQR: 131300.0
# limit_bawah: -80350.0
# limit_atas: 444850.0

# %%
df_duplicate[df_duplicate['median_house_value']>444850.0].shape[0]
# Out:
# 250

# %%
df_duplicate.drop(df_duplicate[df_duplicate['median_house_value']>444850.0].index, inplace=True)

# %%
df_duplicate[df_duplicate['median_house_value']>444850.0].shape[0]
# Out:
# 0

# %%
sns.boxplot(x='median_house_value',data=df_duplicate)
# Out:
# <Axes: xlabel='median_house_value'>

# %%
anomalies(df_duplicate['median_house_value'])
# Out:
# IQR: 126800.0
# limit_bawah: -74800.0
# limit_atas: 432400.0

# %%
df_duplicate[df_duplicate['median_house_value']>432400.0].shape[0]
# Out:
# 73

# %%
df_duplicate.drop(df_duplicate[df_duplicate['median_house_value']>432400.0].index, inplace=True)

# %%
df_duplicate[df_duplicate['median_house_value']>432400.0].shape[0]
# Out:
# 0

# %%
anomalies(df_duplicate['median_house_value'])
# Out:
# IQR: 125675.0
# limit_bawah: -73412.5
# limit_atas: 429287.5

# %%
sns.boxplot(x='median_house_value',data=df_duplicate)
# Out:
# <Axes: xlabel='median_house_value'>

# %% [markdown]
# Mengecek distribusi data pada kolom kategorikal

# %%
df_duplicate['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     5774
# INLAND        4507
# NEAR OCEAN    1634
# NEAR BAY      1399
# ISLAND           2
# Name: count, dtype: int64

# %% [markdown]
# Ada 2 baris data yang `ocean_proximity` nya adalah "ISLAND" maka akan dihapus

# %%
# hapus baris data yang 'ocean_proximity' == 'ISLAND'
df_duplicate.drop(df_duplicate[df_duplicate['ocean_proximity']=='ISLAND'].index, inplace=True)

# %%
# baris tersebut sudah terhapus
df_duplicate['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     5774
# INLAND        4507
# NEAR OCEAN    1634
# NEAR BAY      1399
# Name: count, dtype: int64

# %%
df_duplicate[df_duplicate['median_house_value']>429287.5].shape[0]/df_duplicate.shape[0]
# Out:
# 0.0015021781583295778

# %% [markdown]
# Setelah penghapusan outlier, ternyata tetap ada outlier di kolom `median_house_value`. Walaupun presentase outlier menurun menjadi 0,15%, namun tetap akan ada outlier setelah penghapusan outlier selanjutnya. Dan itu akan terus berulang terus menerus. Kita akan menggunakan metrik evaluasi **MAE** & **MAPE** yang lebih toleran (tidak sensitif) terhadap outlier.

# %% [markdown]
# ### **5. Korelasi Data**

# %% [markdown]
# Selanjutnya akan dilihat korelasi data pada dataset, menggunakan heatmap untuk melihat korelasi antar fitur target dengan fitur numerik yang lain.

# %%
numeric_data = df_duplicate.select_dtypes(exclude='object')
numeric_corr = numeric_data.corr()
f, ax = plt.subplots(figsize=(12,1))
sns.heatmap(numeric_corr.abs().sort_values(by=['median_house_value'], ascending=False).head(1),annot=True)
plt.title('Correlation Numeric features with median_house_value', fontsize=20)
plt.show()

# %% [markdown]
# Jika ditinjau dari hasil nilai korelasinya, beberapa fitur memiliki korelasi rendah. Oleh karena itu kita akan mencoba menambah beberapa fitur untuk memperkuat model:
# * `bedrooms_per_room`: jumlah total kamar tidur per total kamar
# * `population_per_household`: jumlah total orang yang tinggal dalam satu rumah tangga

# %%
df_duplicate['bedrooms_per_room'] = df_duplicate['total_bedrooms']/df_duplicate['total_rooms']
df_duplicate['population_per_household'] = df_duplicate['population']/df_duplicate['households']

# %%
numeric_data = df_duplicate.select_dtypes(exclude='object')
numeric_corr = numeric_data.corr()
f, ax = plt.subplots(figsize=(12,1))
sns.heatmap(numeric_corr.abs().sort_values(by=['median_house_value'], ascending=False).head(1),annot=True)
plt.title('Correlation Numeric features with median_house_value', fontsize=20)
plt.show()

# %% [markdown]
# Bisa dilihat fitur `bedrooms_per_room` memiliki korelasi lebih tinggi daripada fitur `total_bedrooms`. Sementara fitur `population_per_household` memiliki feature importance lebih tinggi dari `population` (sebelumnya sudah dilakukan percobaan).
# Sehingga fitur `total_bedrooms` & `population` akan dilakukan tindakan berupa penghapusan fitur tersebut.

# %%
df_duplicate.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -119.79     36.73                52.0        112.0            28.0
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
#
#    population  households  median_income ocean_proximity  median_house_value  \
# 0       193.0        40.0         1.9750          INLAND             47500.0
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0
#
#    bedrooms_per_room  population_per_household
# ...

# %% [markdown]
# ### **6. Bining Data**

# %% [markdown]
# Selanjutnya akan dilakukan binning data untuk tahu sebaran frekuensi data

# %%
df_duplicate_bin = df_duplicate.copy()

# %%
df_duplicate_bin['median_house_value eqintv'] = pd.cut(df_duplicate_bin['median_house_value'],10)
df_duplicate_bin['median_house_value eqintv encode'] = pd.cut(df_duplicate_bin['median_house_value'],10,labels=range(1,11))

# %%
df_duplicate_bin['median_house_value eqfreq'] = pd.qcut(df_duplicate_bin['median_house_value'],10)
df_duplicate_bin['median_house_value eqfreq encode'] = pd.qcut(df_duplicate_bin['median_house_value'],10,labels=range(1,11))

# %%
df_duplicate_bin.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -119.79     36.73                52.0        112.0            28.0
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
#
#    population  households  median_income ocean_proximity  median_house_value  \
# 0       193.0        40.0         1.9750          INLAND             47500.0
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0
#
# ...

# %%
df_duplicate_bin['median_house_value eqintv'].value_counts()
# Out:
# median_house_value eqintv
# (140219.3, 181959.4]    2564
# (98479.2, 140219.3]     2285
# (56739.1, 98479.2]      2070
# (181959.4, 223699.5]    1955
# (223699.5, 265439.6]    1564
# (265439.6, 307179.7]     987
# (307179.7, 348919.8]     679
# (348919.8, 390659.9]     557
# (14581.599, 56739.1]     347
# (390659.9, 432400.0]     306
# Name: count, dtype: int64

# %%
df_duplicate_bin['median_house_value eqfreq'].value_counts()
# Out:
# median_house_value eqfreq
# (194100.0, 225000.0]    1348
# (80030.0, 103000.0]     1336
# (170900.0, 194100.0]    1335
# (151220.0, 170900.0]    1334
# (14998.999, 80030.0]    1332
# (103000.0, 127500.0]    1332
# (321370.0, 432400.0]    1332
# (261300.0, 321370.0]    1330
# (127500.0, 151220.0]    1326
# (225000.0, 261300.0]    1309
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (14448, 10)

# %%
df_duplicate.shape
# Out:
# (13314, 12)

# %% [markdown]
# - - -

# %% [markdown]
# ## **E. Machine Learning Modeling**

# %% [markdown]
# Karena `ocean_proximity` adalah data kategorikal, yang memiliki 5 kategori namun sekarang menjadi 4 kategori karena 'ISLAND' telah dihapus. Oleh karena itu `ocean_proximity` akan menggunakan OneHotEncoding.
# Untuk data numerikal akan menggunakan scaling yaitu RobustScaler.

# %%
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV

from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.svm import SVR

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
df_duplicate.describe(include='all')
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   13314.000000  13314.000000        13314.000000  13314.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.553767     35.657413           28.246507   2615.565946
# std         2.007991      2.159405           12.486414   2187.791710
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.730000     33.930000           18.000000   1438.000000
# 50%      -118.500000     34.280000           28.000000   2102.000000
# 75%      -117.980000     37.730000           37.000000   3112.000000
# max      -114.310000     41.950000           52.000000  32627.000000
#
#         total_bedrooms    population    households  median_income  \
# count     13314.000000  13314.000000  13314.000000   13314.000000
# ...

# %% [markdown]
# ### **1. Encoding**

# %%
# Mengubah fitur kategorikal menjadi numerikal

transform= ColumnTransformer(
    [
    ('Onehot', OneHotEncoder(drop='first', handle_unknown='ignore'), ['ocean_proximity']),
    ('scaler', RobustScaler(), ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households',	'median_income']),
    ], remainder= 'passthrough'
)

transform
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Onehot',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  ['ocean_proximity']),
#                                 ('scaler', RobustScaler(),
#                                  ['housing_median_age', 'total_rooms',
#                                   'total_bedrooms', 'population', 'households',
#                                   'median_income'])])

# %% [markdown]
# ### **2. Data Spliting**

# %%
# Memisahkan data independen variabel dengan target
X = df_duplicate.drop(['median_house_value'], axis=1)
y = df_duplicate['median_house_value']

# %% [markdown]
# Train and Test Spliting

# %%
# Splitting data training dan test dengan proporsi 70:30
X_train, X_test, y_train, y_test= train_test_split(
    X,
    y,  
    test_size=0.3,
    random_state=1)

# %%
# import libraries
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.svm import SVR
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **3. Model Benchmarking**

# %%
lr=LinearRegression()
knn=KNeighborsRegressor()
dt=DecisionTreeRegressor()
rf = RandomForestRegressor(random_state=1)
xgb = XGBRegressor(random_state=1)
lasso = Lasso()
svr = SVR()

models=[lr,knn,dt,rf,xgb,lasso,svr]

rmse = []
rmse_mean = []
rmse_std = []

mae = []
mae_mean = []
mae_std= []

mape = []
mape_mean = []
mape_std = []


for i in models:
    estimator= Pipeline([
        ('preprocessing', transform),
        ('scaler', RobustScaler()),
        ('model', i)
    ])

    crossval_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=5, 
        scoring='neg_root_mean_squared_error'
        )
    
    rmse.append(crossval_rmse)
    rmse_mean.append(crossval_rmse.mean())
    rmse_std.append(crossval_rmse.std())

    crossval_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=5, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )
    
    mae.append(crossval_mae)
    mae_mean.append(crossval_mae.mean())
    mae_std.append(crossval_mae.std())


    crossval_mape = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=5, 
        scoring='neg_mean_absolute_percentage_error'
        )
    
    mape.append(crossval_mape)
    mape_mean.append(crossval_mape.mean())
    mape_std.append(crossval_mape.std())
    
pd.DataFrame({
    'Model': ['Linear Regression', 'KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor', 'XGBoost Regressor', 'Lasso Regressor', 'SVR'],
    'rata-rata RMSE': rmse_mean,
    'rata-rata MAE': mae_mean,
    'rata-rata MAPE': mape_mean,
    'Std RMSE': rmse_std,
    'Std MAE': mae_std,
    'Std MAPE': mape_std
})
# Out:
#                     Model  rata-rata RMSE  rata-rata MAE  rata-rata MAPE  \
# 0       Linear Regression   -55133.927638  -40980.169779       -0.262075
# 1           KNN Regressor   -51601.841076  -37220.330575       -0.230532
# 2  DecisionTree Regressor   -60014.796189  -41449.306260       -0.247220
# 3  RandomForest Regressor   -42671.063228  -29822.843773       -0.184222
# 4       XGBoost Regressor   -40389.736322  -28170.941664       -0.172954
# 5         Lasso Regressor   -55134.070413  -40979.890064       -0.262066
# 6                     SVR   -89868.337636  -70939.609478       -0.488067
#
#       Std RMSE     Std MAE  Std MAPE
# 0  1146.703198  381.844879  0.008844
# 1   667.241663  527.826220  0.009107
# 2  1522.627332  800.496925  0.009446
# 3  1081.237671  724.729965  0.006888
# 4   769.099864  466.873472  0.006202
# 5  1147.350355  382.007465  0.008844
# 6  1097.029075  890.896354  0.019438

# %% [markdown]
# Dapat dilihat dari nilai rerata MAE, MAPE, dan RMSE model XGBoost dan RandomForest adalah yang terbaik diantara 7 permodelan yang dipakai, karena nilai erornya mendekati nol. Maka dari itu akan digunakan 2 model tersebut untuk memprediksi ke data test.

# %% [markdown]
# ### **4. Hyperparameter Tuning**

# %%
models= {
    'XGBoost': XGBRegressor(random_state=1),
    'RandomForest': RandomForestRegressor(random_state=1)
}

rmse=[]
mae=[]
mape=[]

for i in models:
    model = Pipeline([
        ('preprocessing', transform),
        ('scaler', RobustScaler()),
        ('model', models[i])
        ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    mae.append(mean_absolute_error(y_test, y_pred))
    mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_sblm= pd.DataFrame({'RMSE': rmse, 'MAE': mae, 'MAPE': mape}, index=models.keys())
score_sblm
# Out:
#                       RMSE           MAE      MAPE
# XGBoost       41377.921300  28244.591248  0.172746
# RandomForest  42635.265778  29175.503277  0.178322

# %% [markdown]
# Ternyata setelah dilakukan Benchmarking diketahui bahwa model XGBoost memiliki nilai yang lebih kecil erornya dibandingkan dengan model RandomForest. Maka dari itu, pemodelan akan difokuskan pada model XGBoost saja.

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=1, verbosity=0)

max_depth = list(np.arange(1, 11))
learning_rate = list(np.arange(1, 100)/100)
n_estimators = list(np.arange(100, 201))
subsample = list(np.arange(2, 10)/10)
gamma = list(np.arange(1, 11))
colsample_bytree = list(np.arange(1, 10)/10)
reg_alpha = list(np.logspace(-3, 1, 10)) 


hyperparam_space_xgb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__gamma': gamma,
    'model__colsample_bytree': colsample_bytree,
    'model__reg_alpha': reg_alpha
}

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transform),
        ('scaler', RobustScaler()),
        ('model', xgb)
        ])

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb,
    param_distributions = hyperparam_space_xgb, 
    n_iter = 300,
    cv = 5, 
    scoring = 'neg_root_mean_squared_error',
    n_jobs = -1,
    refit = True,
    random_state = 1  
)

random_xgb.fit(X_train, y_train)

print('XGBoost')
print('Best_score: \n', random_xgb.best_score_)
print('Best_params: \n', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score:
#  -39936.18185970825
# Best_params:
#  {'model__subsample': 0.8, 'model__reg_alpha': 0.1668100537200059, 'model__n_estimators': 195, 'model__max_depth': 9, 'model__learning_rate': 0.14, 'model__gamma': 2, 'model__colsample_bytree': 0.9}

# %% [markdown]
# Dikarenakan sudah diketahui nilai parameter terbaik, selanjutnya hasil tersebut akan diimplementasikan ke dalam data test yang ada.

# %%
xgb_tuned = random_xgb.best_estimator_
model={'XGB': XGBRegressor(random_state=1)}

xgb_tuned.fit(X_train, y_train)

y_pred_xgb_tuned = xgb_tuned.predict(X_test)

rmse_xgb_tuned = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuned))
mae_xgb_tuned = mean_absolute_error(y_test, y_pred_xgb_tuned)
mape_xgb_tuned = mean_absolute_percentage_error(y_test, y_pred_xgb_tuned)

score_after = pd.DataFrame({'RMSE': rmse_xgb_tuned, 'MAE': mae_xgb_tuned, 'MAPE': mape_xgb_tuned}, index=model.keys())
score_after
# Out:
#              RMSE          MAE      MAPE
# XGB  40272.210856  27431.04796  0.167215

# %%
xgb_sblm = pd.DataFrame(score_sblm.loc['XGBoost']).T

print('Sebelum Tuning: \n')
display(xgb_sblm)
print('Sesudah Tuning: \n')
display(score_after)
# Out:
# Sebelum Tuning:
#                RMSE           MAE      MAPE
# XGBoost  41377.9213  28244.591248  0.172746
# Sesudah Tuning:
#              RMSE          MAE      MAPE
# XGB  40272.210856  27431.04796  0.167215

# %% [markdown]
# Selanjutnya akan ditampilkan grafik untuk melihat akurasi model yang sudah dibuat

# %%
sns.scatterplot(x=y_test, y=y_pred_xgb_tuned)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')

plt.title('Harga Aktual vs Harga Prediksi')
plt.xlabel('Harga Aktual' )
plt.ylabel('Harga Prediksi')

plt.show()

# %%
harga = pd.DataFrame({'Prediksi Harga': y_pred_xgb_tuned, 'Harga Aktual': y_test})
harga[harga['Prediksi Harga']<432400]
# Out:
#        Prediksi Harga  Harga Aktual
# 12909   394107.687500      417100.0
# 3032     91666.781250      110700.0
# 855     228566.859375      170200.0
# 6353    145961.234375      113500.0
# 13566   344308.093750      369100.0
# ...               ...           ...
# 11338   257748.218750      228900.0
# 6223     74722.656250       55600.0
# 9823    136233.859375      109900.0
# 12262   330369.125000      275000.0
# 3095    106776.531250       77500.0
#
# [3995 rows x 2 columns]

# %% [markdown]
# #### **5. Feature Importances**
# Untuk dapat mengetahui sebenarnya fitur apa saja yang sangat memengaruhi target (median_house_value), kita dapat mengeceknya melalui function feature_importances.

# %%
xgb_tuned
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Onehot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['ocean_proximity']),
#                                                  ('scaler', RobustScaler(),
#                                                   ['housing_median_age',
#                                                    'total_rooms',
#                                                    'total_bedrooms',
#                                                    'population', 'households',
#                                                    'median_income'])])),
#                 ('scaler', RobustScaler()),
#                 ('model',
#                  XGBRegressor(base_...
# ...

# %%
pd.Series(xgb_tuned['model'].feature_importances_, transform.get_feature_names_out()).sort_values(ascending = False)
# Out:
# Onehot__ocean_proximity_INLAND         0.376940
# scaler__median_income                  0.223292
# remainder__latitude                    0.083574
# remainder__population_per_household    0.074418
# remainder__longitude                   0.072970
# remainder__bedrooms_per_room           0.053666
# scaler__housing_median_age             0.019344
# scaler__households                     0.018574
# Onehot__ocean_proximity_NEAR OCEAN     0.017392
# scaler__total_bedrooms                 0.016897
# scaler__population                     0.015976
# Onehot__ocean_proximity_NEAR BAY       0.013699
# scaler__total_rooms                    0.013260
# dtype: float32

# %% [markdown]
# Didapat hasil bahwa 3 fitur dengan nilai features importances paling tinggi yaitu `ocean_proximity_INLAND`, `median_income`, dan `population_per_household`

# %%
# Plot feature importances
feature_imp = pd.Series(xgb_tuned['model'].feature_importances_, transform.get_feature_names_out()).sort_values(ascending=True)
feature_imp.plot(kind='barh', title='Feature Importances', color='red')
plt.show()

# %% [markdown]
# Dapat dilihat bahwa fitur ocean_proximity == INLAND adalah fitur penting tertinggi nomor 1, lalu nomor 2 adalah fitur median_income, ketiga adalah latitude, dan seterusnya.

# %% [markdown]
# ### **6. Residual Plot**

# %% [markdown]
# **XGBoost**

# %%
residual_bench = y_test-y_pred
residual_tuned = y_test-y_pred_xgb_tuned

plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.scatterplot(x=y_test,y=residual_bench)
plt.axhline(y = 0,color='red')
plt.title('Residual Plot Benchmark Model')

plt.subplot(1,2,2)
sns.scatterplot(x=y_test,y=residual_tuned)
plt.axhline(y = 0,color='red')
plt.title('Residual Plot Tuning Model')
plt.show()

# %% [markdown]
# Dilakukan plot residu yang didapat dari pengurangan data aktual (test) dengan hasil prediksi/tuning. Terlihat dari plotnya, tidak mengilustrasikan sebuah pola khusus. Tetapi bisa dilihat trennya pada harga rumah yang yang rendah, cenderung menghasilkan prediksi yang lebih besar dari aktual (over-estimate). Namun pada harga rumah yang tinggi, hasil prediksi cenderung lebih rendah dari aktual (under-estimate).

# %%
data_bin= pd.DataFrame(y_test).rename(columns={'median_house_value':'actual'})
data_bin['pred'] = y_pred
data_bin['bins'] = pd.cut(x=data_bin['actual'],
                          bins=[14999, 65000, 115400, 165000, 215000, 265000, 315000, 365000, 415000, 465000, 500000],
                          labels=['14999 - 65000', '65000 - 115000', '115400 - 165000', '165000 - 215000', '215000 - 265000',
                                  '2625000 - 315000', '315000 - 365000', '365000 - 415000', '415000 - 465000', '465000 - 500000']) 
data_bin.head()
# Out:
#          actual      pred             bins
# 12909  417100.0  355279.0  415000 - 465000
# 3032   110700.0   73596.0   65000 - 115000
# 855    170200.0  238391.0  165000 - 215000
# 6353   113500.0  140821.0   65000 - 115000
# 13566  369100.0  320665.0  365000 - 415000

# %%
def mape(data_bin):
    return mean_absolute_percentage_error([data_bin['actual']], [data_bin['pred']])

data_bin['mape'] = data_bin[['actual','pred']].apply(mape, axis=1)
data_bin.head()
# Out:
#          actual      pred             bins      mape
# 12909  417100.0  355279.0  415000 - 465000  0.148216
# 3032   110700.0   73596.0   65000 - 115000  0.335176
# 855    170200.0  238391.0  165000 - 215000  0.400652
# 6353   113500.0  140821.0   65000 - 115000  0.240714
# 13566  369100.0  320665.0  365000 - 415000  0.131225

# %%
data_bin.groupby('bins')[['mape']].mean()
# Out:
#                       mape
# bins
# 14999 - 65000     0.411306
# 65000 - 115000    0.246155
# 115400 - 165000   0.159383
# 165000 - 215000   0.133174
# 215000 - 265000   0.130061
# 2625000 - 315000  0.122022
# 315000 - 365000   0.138364
# 365000 - 415000   0.189476
# 415000 - 465000   0.248126
# 465000 - 500000        NaN

# %%
# Membuat figure dan axes
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))

# Countplot
sns.countplot(data=data_bin, x='bins', color='#ba181b', ax=ax1)
ax1.set_ylabel('Jumlah Data', weight='bold')
ax1.set_xlabel('')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, fontsize=8)

# Barplot
data_by = data_bin.groupby('bins')[['mape']].mean()
cols = ['#ffd166' if x < 0.25 else '#03071e' for x in data_by['mape']]
sns.barplot(data=data_bin, x='bins', y='mape',
            palette=cols, ax=ax2,
            estimator='mean',
            ci=None)
ax2.axhline(y=0.25, color='red', ls='--')
ax2.set_ylabel('% MAPE', weight='bold')
ax2.set_xlabel('')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, fontsize=8)

# Mengatur judul dan label sumbu
ax1.set_title('Plot Jumlah Perharga Rumah', weight='bold', fontsize=10)
ax2.set_title('Mean MAPE berdasarkan Bins', weight='bold', fontsize=10)

# Mengatur pemisah antara grafik
plt.subplots_adjust(hspace=1.0)

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan tabel diatas, didapat hasil bahwa :
#
# 1. Tingkat kesalahan tertinggi berada pada harga rumah dengan rentang rendah ($14999 - $65000), lalu pada rentang harga rumah ($65000 - $115000) dan rentang ($415000 - $465000). Menunjukan bahwa model cenderung memiliki kesulitan dalam memprediksi harga rumah pada rentang tersebut.
#
# 2. Tingkat akurasi tertinggi atau dengan eror terendah ada pada rumah dengan rentang harga ($2625000 - $315000). Menunjukan bahwa model memiliki keunggulan dalam memprediksi harga rumah pada rentang tersebut.

# %% [markdown]
# - - -

# %% [markdown]
# ## **F. Conclusion and Recommendation**

# %%
df_duplicate.describe()['median_house_value']
# Out:
# count     13314.000000
# mean     185754.513820
# std       89027.454682
# min       14999.000000
# 25%      115100.000000
# 50%      170900.000000
# 75%      240775.000000
# max      432400.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### **1. Conclusion**

# %% [markdown]
# Berdasarkan hasil permodelan terbaik yaitu **`XGBoost`** maka didapat :
#
# - Dari total 7 model yang dibuat, permodelan XGBoost adalah permodelan terbaik, dibuktikan dari nilai erornya yang paling kecil. Lalu setelah dilakukan tuning pada model tersebut, didapat hasil lebih baik.
# - Fitur `ocean_proximity` dan `median_income` adalah fitur yang korelasinya paling tinggi dalam permodelan ini untuk memprediksi `median_house_value`.
# - Limitasi pada permodelan ini yaitu hanya bisa memprediksi model dengan `median_house_value` pada rentang $14999 sampai dengan $432400 saja.

# %% [markdown]
# ### **2. Recommendation**

# %% [markdown]
# Untuk Model Machine Learning :
#
# - Agar permodelan machine learning lebih optimal, bisa dilakukan optimasi menggunakan GridSearch, karena teknik ini secara sistematis mencoba semua kombinasi hyperparameter yang memungkinkan dari suatu model untuk menemukan kombinasi yang memberikan performa terbaik. Namun kekurangan menggunakan GridSearch ini adalah karena memakan waktu yang cukup lama, karena mencoba semua kombinasi.
# - Sebaiknya dilakukan juga evaluasi lebih lanjut, bisa dengan menerapkan `iterative feature selection` pada model. Tujuan dari iterative feature selection adalah untuk memilih subset fitur yang paling relevan atau memberikan kinerja terbaik untuk suatu model.
#
# Untuk Developer Perumahan (Secara Bisnis) :
#
# - Agar bisa memaksimalkan keuntungan, pihak developer perlu memperhatikan pendapatan perkapita penduduk sekitar. Pada dataset bisa dilihat melalui fitur `median_income`, supaya bisa lebih tepat dalam menempatkan calon pelanggan yang disasar.
#
# Untuk Dataset :
#
# - Dataset ini adalah data tahun 1990, maka dari itu bisa jadi datanya sudah kurang relevan untuk tahun 2023 ini. Perlu dilakukan update harga rumah terbaru, mengingat adanya inflasi yang fluktuatif setiap waktunya.
# - Sebaiknya juga perlu dicari fitur pendukung yang dirasa kuat berpengaruh dalam memprediksi harga rumah. Misalnya fitur `luas_tanah`, `luas_bangunan`, dan `jarak_ke_fasilitas_umum` (rumah sakit, stasiun, halte bis, bandara, sekolah, dll).

# %% [markdown]
# ## **Saving and Load Best Model**

# %%
# pip install pickle

# %%
import pickle

# %%
# best estimator
xgb_tuned = random_xgb.best_estimator_

# fitting model
xgb_tuned.fit(X, y)

# save
pickle.dump(xgb_tuned, open('model_xgboost_for_price_regression.sav', 'wb')) # 'wb' (wright binnary) untuk menyimpannya

# %%
# load model
model_loaded_pickle = pickle.load(open('model_xgboost_for_price_regression.sav', 'rb')) # 'rb' (read) untuk membaca modelnya

# %% [markdown]
# - - -

# %% [markdown]
# # Thank You

# %%
# baris yang ingin diprediksi nilai actual serta predictnya
X_test.iloc[[10]]
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 932    -118.31     33.96                48.0       2015.0           356.0
#
#      population  households  median_income ocean_proximity  bedrooms_per_room  \
# 932      1020.0       338.0         4.0625       <1H OCEAN           0.176675
#
#      population_per_household
# 932                  3.017751

# %%
# harga actual
y_test.iloc[10]
# Out:
# 138700.0

# %%
# harga prediksi dari permodelan machine learning
model_loaded_pickle.predict(X_test.iloc[[10]])
# Out:
# array([146999.4], dtype=float32)
